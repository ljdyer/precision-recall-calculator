# %%
import sys

# %%
import pandas as pd

# %%
# Delete precision-recall-calculator folder to ensures that any changes to the repo are reflected
# !rm -rf 'precision-recall-calculator'
# Clone precision-recall-calculator repo
# !git clone https://github.com/ljdyer/precision-recall-calculator.git
# Add precision-recall-calculator to PYTHONPATH
sys.path.append('precision-recall-calculator')
# Out:
# Cloning into 'precision-recall-calculator'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 168 (delta 97), reused 123 (delta 55), pack-reused 0
# Receiving objects: 100% (168/168), 60.20 KiB | 10.03 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from precision_recall_calculator.main import PrecisionRecallCalculator

# %%
RESULTS_DF_PATH = 'drive/MyDrive/Group Assignment/Results/end_to_end.csv'
results_df_csv = pd.read_csv(RESULTS_DF_PATH)
reference = results_df_csv['reference'].to_list()
hypothesis = results_df_csv['model_5_result'].to_list()
prc_TED = PrecisionRecallCalculator(
    reference, hypothesis, True, '., ')
# Out:
# Getting confusion matrices...
#   0%|          | 0/800 [00:00<?, ?it/s]
# Initialisation complete.

# %%
prc_TED.show_precision_recall_fscore()
# Out:
#                 Precision    Recall   F-score
# Periods ('.')    0.554469  0.512819  0.532831
# Commas (',')     0.518108  0.222315  0.311128
# Spaces (' ')     0.967771  0.976422  0.972077
# Capitalisation   0.725384  0.471161  0.571266
# All features     0.919098  0.861036  0.889120

# %%
prc_TED.show_confusion_matrices()
# Out:
# Periods ('.')
#                    Hypothesis
#                      positive negative
# Reference positive      47666    45283
#           negative      38301  6193349
# Commas (',')
#                    Hypothesis
#                      positive negative
# Reference positive      24663    86274
#           negative      22939  6190723
# Spaces (' ')
#                    Hypothesis
#                      positive negative
# Reference positive    1408450    34010
#           negative      46905  4835234
# Capitalisation
#                    Hypothesis
#                      positive negative
# Reference positive      76396    85748
#           negative      28922  6133533
# All features
#                    Hypothesis
#                      positive  negative
# Reference positive    1557175    251315
#           negative     137067  23352839
